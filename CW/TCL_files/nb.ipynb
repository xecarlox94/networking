# %%
import tracefile


df = tracefile.get_df("top2.tr")


df.head()
# Out:
#   event  time  src_node  dst_node packet_type  packet_size  flags  \
# 0     +   0.0         6         4         tcp           40      2
# 1     -   0.0         6         4         tcp           40      2
# 2     +   0.0         4         6         cbr         1000      1
# 3     -   0.0         4         6         cbr         1000      1
# 4     +   0.0         7         5         tcp           40      2
#
#    fragment_id  src_address  dst_address  seq_number  packet_id
# 0          6.0          4.2            0           4        NaN
# 1          6.0          4.2            0           4        NaN
# 2          4.3          6.1            0           5        NaN
# 3          4.3          6.1            0           5        NaN
# 4          7.0          5.2            0           6        NaN

# %%
tracefile.packet_delivery_ratio(df)
# Out:
# 0.990682463285203

# %%
tracefile.total_dropped_packet(df)
# Out:
# 292

# %%
tracefile.total_lost_packets(df)
# Out:
# 604

# %%
tracefile.total_dropped_packet(df)
# Out:
# 292

# %%
tracefile.throughput(df)
# Out:
# 98.4501287555451
