# %%
import tracefile


df = tracefile.get_df("top2.tr")


df.head()
# Out:
#   event  time  src_node  dst_node packet_type  packet_size  flags  \
# 0     +   0.0         6         4         tcp           40      2
# 1     -   0.0         6         4         tcp           40      2
# 2     +   0.0         4         6         cbr         1000      1
# 3     -   0.0         4         6         cbr         1000      1
# 4     +   0.0         7         5         tcp           40      2
#
#    fragment_id  src_address  dst_address  seq_number  packet_id
# 0          6.0          4.2            0           4        NaN
# 1          6.0          4.2            0           4        NaN
# 2          4.3          6.1            0           5        NaN
# 3          4.3          6.1            0           5        NaN
# 4          7.0          5.2            0           6        NaN

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 100, 200, 300, 400])
y = x * 3

fig, ax = plt.subplots()

ax.plot(x, y, label='Distance Vector', marker="o")

ax.plot(x, y - 50, label='Using the dashes parameter', marker="o")

ax.legend()
plt.show()
